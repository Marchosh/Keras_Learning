# %%
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import *

# %%
training_data_df = pd.read_csv("06\sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# %%
# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu', name='layer_1'))
model.add(Dense(100, activation='relu', name='layer_2'))
model.add(Dense(50, activation='relu', name='layer_3'))
model.add(Dense(1, activation='linear', name='output_layer'))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Create a TensorBoard logger
logger = keras.callbacks.TensorBoard(
    log_dir='logs',
    write_graph=True,
    histogram_freq=5
)

# %%
# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2,
    callbacks=[logger]
)
# Out:
# Epoch 1/50
# 32/32 - 1s - loss: 0.0285 - 607ms/epoch - 19ms/step
# Epoch 2/50
# 32/32 - 0s - loss: 0.0040 - 108ms/epoch - 3ms/step
# Epoch 3/50
# 32/32 - 0s - loss: 0.0016 - 84ms/epoch - 3ms/step
# Epoch 4/50
# 32/32 - 0s - loss: 8.1525e-04 - 66ms/epoch - 2ms/step
# Epoch 5/50
# 32/32 - 0s - loss: 5.1887e-04 - 138ms/epoch - 4ms/step
# Epoch 6/50
# 32/32 - 0s - loss: 3.2237e-04 - 162ms/epoch - 5ms/step
# Epoch 7/50
# 32/32 - 0s - loss: 2.2934e-04 - 83ms/epoch - 3ms/step
# Epoch 8/50
# 32/32 - 0s - loss: 1.6298e-04 - 87ms/epoch - 3ms/step
# Epoch 9/50
# 32/32 - 0s - loss: 1.2472e-04 - 62ms/epoch - 2ms/step
# Epoch 10/50
# 32/32 - 0s - loss: 9.9266e-05 - 122ms/epoch - 4ms/step
# Epoch 11/50
# 32/32 - 0s - loss: 8.9069e-05 - 238ms/epoch - 7ms/step
# Epoch 12/50
# 32/32 - 0s - loss: 8.2022e-05 - 160ms/epoch - 5ms/step
# Epoch 13/50
# 32/32 - 0s - loss: 6.8478e-05 - 63ms/epoch - 2ms/step
# Epoch 14/50
# 32/32 - 0s - loss: 7.2480e-05 - 51ms/epoch - 2ms/step
# Epoch 15/50
# 32/32 - 0s - loss: 6.1292e-05 - 55ms/epoch - 2ms/step
# Epoch 16/50
# 32/32 - 0s - loss: 5.6671e-05 - 251ms/epoch - 8ms/step
# Epoch 17/50
# 32/32 - 0s - loss: 4.8808e-05 - 151ms/epoch - 5ms/step
# Epoch 18/50
# 32/32 - 0s - loss: 4.3194e-05 - 115ms/epoch - 4ms/step
# Epoch 19/50
# 32/32 - 0s - loss: 4.2664e-05 - 96ms/epoch - 3ms/step
# Epoch 20/50
# 32/32 - 0s - loss: 4.4216e-05 - 65ms/epoch - 2ms/step
# Epoch 21/50
# 32/32 - 0s - loss: 4.3955e-05 - 272ms/epoch - 8ms/step
# Epoch 22/50
# 32/32 - 0s - loss: 4.0334e-05 - 139ms/epoch - 4ms/step
# Epoch 23/50
# 32/32 - 0s - loss: 3.9730e-05 - 138ms/epoch - 4ms/step
# Epoch 24/50
# 32/32 - 0s - loss: 3.8600e-05 - 141ms/epoch - 4ms/step
# Epoch 25/50
# 32/32 - 0s - loss: 3.2681e-05 - 137ms/epoch - 4ms/step
# Epoch 26/50
# 32/32 - 0s - loss: 3.2827e-05 - 225ms/epoch - 7ms/step
# Epoch 27/50
# 32/32 - 0s - loss: 2.9317e-05 - 55ms/epoch - 2ms/step
# Epoch 28/50
# 32/32 - 0s - loss: 2.5385e-05 - 129ms/epoch - 4ms/step
# Epoch 29/50
# 32/32 - 0s - loss: 2.9133e-05 - 124ms/epoch - 4ms/step
# Epoch 30/50
# 32/32 - 0s - loss: 2.8265e-05 - 140ms/epoch - 4ms/step
# Epoch 31/50
# 32/32 - 0s - loss: 3.1313e-05 - 238ms/epoch - 7ms/step
# Epoch 32/50
# 32/32 - 0s - loss: 2.5649e-05 - 51ms/epoch - 2ms/step
# Epoch 33/50
# 32/32 - 0s - loss: 2.8644e-05 - 56ms/epoch - 2ms/step
# Epoch 34/50
# 32/32 - 0s - loss: 3.4639e-05 - 51ms/epoch - 2ms/step
# Epoch 35/50
# 32/32 - 0s - loss: 2.6592e-05 - 77ms/epoch - 2ms/step
# Epoch 36/50
# 32/32 - 0s - loss: 2.5131e-05 - 119ms/epoch - 4ms/step
# Epoch 37/50
# 32/32 - 0s - loss: 2.7780e-05 - 65ms/epoch - 2ms/step
# Epoch 38/50
# 32/32 - 0s - loss: 2.3290e-05 - 52ms/epoch - 2ms/step
# Epoch 39/50
# 32/32 - 0s - loss: 2.6516e-05 - 55ms/epoch - 2ms/step
# Epoch 40/50
# 32/32 - 0s - loss: 2.0239e-05 - 54ms/epoch - 2ms/step
# Epoch 41/50
# 32/32 - 0s - loss: 2.0013e-05 - 109ms/epoch - 3ms/step
# Epoch 42/50
# 32/32 - 0s - loss: 2.9892e-05 - 64ms/epoch - 2ms/step
# Epoch 43/50
# 32/32 - 0s - loss: 3.1802e-05 - 87ms/epoch - 3ms/step
# Epoch 44/50
# 32/32 - 0s - loss: 2.2975e-05 - 129ms/epoch - 4ms/step
# Epoch 45/50
# 32/32 - 0s - loss: 2.3184e-05 - 105ms/epoch - 3ms/step
# Epoch 46/50
# 32/32 - 0s - loss: 2.4335e-05 - 219ms/epoch - 7ms/step
# Epoch 47/50
# 32/32 - 0s - loss: 3.1860e-05 - 129ms/epoch - 4ms/step
# Epoch 48/50
# 32/32 - 0s - loss: 2.5848e-05 - 128ms/epoch - 4ms/step
# Epoch 49/50
# 32/32 - 0s - loss: 2.3204e-05 - 138ms/epoch - 4ms/step
# Epoch 50/50
# 32/32 - 0s - loss: 2.0867e-05 - 139ms/epoch - 4ms/step

# %%
# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))
# Out:
# The mean squared error (MSE) for the test data set is: 6.79635995766148e-05

# %%
RUN_NAME = "run 2 with 5 nodes"

# Define the model
model = Sequential()
model.add(Dense(5, input_dim=9, activation='relu', name='layer_1'))
model.add(Dense(100, activation='relu', name='layer_2'))
model.add(Dense(50, activation='relu', name='layer_3'))
model.add(Dense(1, activation='linear', name='output_layer'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Create a TensorBoard logger
logger = keras.callbacks.TensorBoard(
    log_dir='logs/{}'.format(RUN_NAME),
    write_graph=True,
    histogram_freq=5
)

# %%
# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2,
    callbacks=[logger]
)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))
# Out:
# Epoch 1/50
# 32/32 - 1s - loss: 0.0412 - 502ms/epoch - 16ms/step
# Epoch 2/50
# 32/32 - 0s - loss: 0.0232 - 119ms/epoch - 4ms/step
# Epoch 3/50
# 32/32 - 0s - loss: 0.0215 - 117ms/epoch - 4ms/step
# Epoch 4/50
# 32/32 - 0s - loss: 0.0198 - 128ms/epoch - 4ms/step
# Epoch 5/50
# 32/32 - 0s - loss: 0.0180 - 130ms/epoch - 4ms/step
# Epoch 6/50
# 32/32 - 0s - loss: 0.0163 - 166ms/epoch - 5ms/step
# Epoch 7/50
# 32/32 - 0s - loss: 0.0150 - 139ms/epoch - 4ms/step
# Epoch 8/50
# 32/32 - 0s - loss: 0.0136 - 140ms/epoch - 4ms/step
# Epoch 9/50
# 32/32 - 0s - loss: 0.0120 - 127ms/epoch - 4ms/step
# Epoch 10/50
# 32/32 - 0s - loss: 0.0108 - 140ms/epoch - 4ms/step
# Epoch 11/50
# 32/32 - 0s - loss: 0.0094 - 282ms/epoch - 9ms/step
# Epoch 12/50
# 32/32 - 0s - loss: 0.0084 - 83ms/epoch - 3ms/step
# Epoch 13/50
# 32/32 - 0s - loss: 0.0077 - 55ms/epoch - 2ms/step
# Epoch 14/50
# 32/32 - 0s - loss: 0.0065 - 64ms/epoch - 2ms/step
# Epoch 15/50
# 32/32 - 0s - loss: 0.0057 - 112ms/epoch - 3ms/step
# Epoch 16/50
# 32/32 - 0s - loss: 0.0053 - 260ms/epoch - 8ms/step
# Epoch 17/50
# 32/32 - 0s - loss: 0.0048 - 135ms/epoch - 4ms/step
# Epoch 18/50
# 32/32 - 0s - loss: 0.0045 - 132ms/epoch - 4ms/step
# Epoch 19/50
# 32/32 - 0s - loss: 0.0040 - 135ms/epoch - 4ms/step
# Epoch 20/50
# 32/32 - 0s - loss: 0.0033 - 111ms/epoch - 3ms/step
# Epoch 21/50
# 32/32 - 0s - loss: 0.0029 - 115ms/epoch - 4ms/step
# Epoch 22/50
# 32/32 - 0s - loss: 0.0026 - 109ms/epoch - 3ms/step
# Epoch 23/50
# 32/32 - 0s - loss: 0.0024 - 136ms/epoch - 4ms/step
# Epoch 24/50
# 32/32 - 0s - loss: 0.0019 - 72ms/epoch - 2ms/step
# Epoch 25/50
# 32/32 - 0s - loss: 0.0016 - 122ms/epoch - 4ms/step
# Epoch 26/50
# 32/32 - 0s - loss: 0.0014 - 225ms/epoch - 7ms/step
# Epoch 27/50
# 32/32 - 0s - loss: 0.0013 - 65ms/epoch - 2ms/step
# Epoch 28/50
# 32/32 - 0s - loss: 0.0011 - 53ms/epoch - 2ms/step
# Epoch 29/50
# 32/32 - 0s - loss: 8.5784e-04 - 55ms/epoch - 2ms/step
# Epoch 30/50
# 32/32 - 0s - loss: 7.3151e-04 - 62ms/epoch - 2ms/step
# Epoch 31/50
# 32/32 - 0s - loss: 6.7829e-04 - 229ms/epoch - 7ms/step
# Epoch 32/50
# 32/32 - 0s - loss: 5.8155e-04 - 54ms/epoch - 2ms/step
# Epoch 33/50
# 32/32 - 0s - loss: 5.8748e-04 - 65ms/epoch - 2ms/step
# Epoch 34/50
# 32/32 - 0s - loss: 5.6016e-04 - 136ms/epoch - 4ms/step
# Epoch 35/50
# 32/32 - 0s - loss: 4.1696e-04 - 138ms/epoch - 4ms/step
# Epoch 36/50
# 32/32 - 0s - loss: 3.7044e-04 - 230ms/epoch - 7ms/step
# Epoch 37/50
# 32/32 - 0s - loss: 3.3646e-04 - 54ms/epoch - 2ms/step
# Epoch 38/50
# 32/32 - 0s - loss: 3.2026e-04 - 60ms/epoch - 2ms/step
# Epoch 39/50
# 32/32 - 0s - loss: 3.0364e-04 - 108ms/epoch - 3ms/step
# Epoch 40/50
# 32/32 - 0s - loss: 2.9695e-04 - 128ms/epoch - 4ms/step
# Epoch 41/50
# 32/32 - 0s - loss: 2.8926e-04 - 264ms/epoch - 8ms/step
# Epoch 42/50
# 32/32 - 0s - loss: 2.6529e-04 - 129ms/epoch - 4ms/step
# Epoch 43/50
# 32/32 - 0s - loss: 2.4720e-04 - 117ms/epoch - 4ms/step
# Epoch 44/50
# 32/32 - 0s - loss: 2.4243e-04 - 77ms/epoch - 2ms/step
# Epoch 45/50
# 32/32 - 0s - loss: 2.4396e-04 - 64ms/epoch - 2ms/step
# Epoch 46/50
# 32/32 - 0s - loss: 2.1568e-04 - 310ms/epoch - 10ms/step
# Epoch 47/50
# 32/32 - 0s - loss: 2.0478e-04 - 127ms/epoch - 4ms/step
# Epoch 48/50
# 32/32 - 0s - loss: 1.9931e-04 - 133ms/epoch - 4ms/step
# Epoch 49/50
# 32/32 - 0s - loss: 1.9340e-04 - 139ms/epoch - 4ms/step
# Epoch 50/50
# 32/32 - 0s - loss: 1.8419e-04 - 129ms/epoch - 4ms/step
# The mean squared error (MSE) for the test data set is: 0.00023001345107331872

# %% [markdown]
# # Visualize using tesnor board from termnial

# %%
# !tensorboard --logdir=logs
